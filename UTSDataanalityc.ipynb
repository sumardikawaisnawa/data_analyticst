# %% [markdown]
# <a href="https://colab.research.google.com/github/sumardikawaisnawa/data_analyticst/blob/main/UTSDataanalityc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
#Check the present working directory using pwd command
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle datasets download -d alrizacelk/moto-gp-world-championship19492022
# Out:
# ...
#   0% 0.00/33.9k [00:00<?, ?B/s]
# 100% 33.9k/33.9k [00:00<00:00, 6.45MB/s]

# %%
# !ls
# Out:
# cash_flow.csv  map_ticker_to_company.csv
# kaggle.json    moto-gp-world-championship19492022.zip

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  moto-gp-world-championship19492022.zip
#   inflating: constructure-world-championship.csv
#   inflating: grand-prix-events-held.csv
#   inflating: grand-prix-race-winners.csv
#   inflating: riders-finishing-positions.csv
#   inflating: riders-info.csv
#   inflating: same-nation-podium-lockouts.csv

# %%
import pandas as pd

# %%
df = pd.read_csv(r'same-nation-podium-lockouts.csv')

# %%
df.head()
# Out:
#    Season                                  Track Riders` Nation    Class
# 0    2022                    Termas de Río Hondo             ES  MotoGP™
# 1    2021                  Circuit Ricardo Tormo             ES   Moto3™
# 2    2021  Misano World Circuit Marco Simoncelli             IT   MotoE™
# 3    2021  Misano World Circuit Marco Simoncelli             IT   Moto3™
# 4    2021                    Silverstone Circuit             IT   Moto3™

# %%
df = pd.read_csv(r'constructure-world-championship.csv')

# %%
df.head()
# Out:
#    Season Constructor    Class
# 0    2021      Yamaha  MotoGP™
# 1    2021       Kalex   Moto2™
# 2    2021         KTM   Moto3™
# 3    2021    Energica   MotoE™
# 4    2020      Suzuki  MotoGP™

# %%
df = pd.read_csv(r'grand-prix-events-held.csv')

# %%
df.head()
# Out:
#    Times                            Track Country
# 0    280                 TT Circuit Assen      NL
# 1    168                Automotodrom Brno      CZ
# 2    131                Spa-Francorchamps      BE
# 3    125                      Sachsenring      DE
# 4    118  Circuito de Jerez - Angel Nieto      ES

# %%
df = pd.read_csv(r'grand-prix-race-winners.csv')

# %%
df.head()
# Out:
#                    Circuit    Class Constructor Country            Rider  \
# 0  Circuit Of The Americas   Moto3™         KTM      ES      Jaume Masia
# 1  Circuit Of The Americas   Moto2™       Kalex      IT    Tony Arbolino
# 2  Circuit Of The Americas  MotoGP™      Ducati      IT  Enea Bastianini
# 3      Termas de Río Hondo   Moto3™      GASGAS      ES    Sergio Garcia
# 4      Termas de Río Hondo  MotoGP™     Aprilia      ES  Aleix Espargaro
#
#    Season
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022

# %%
df = pd.read_csv(r'riders-finishing-positions.csv')

# %%
df.head()
# Out:
#               Rider  Victories  NumberofSecond  NumberofThird  Numberof4th  \
# 0  Giacomo Agostini        122              67             53           48
# 1   Valentino Rossi        115              52             47           38
# 2       Angel Nieto         90              51             40           35
# 3      Marc Marquez         85              44             36           28
# 4     Mike Hailwood         76              41             33           26
#
#    Numberof5th  Numberof6th Country
# 0           34           24      IT
# 1           30           21      IT
# 2           25           21      ES
# 3           23           21      ES
# 4           22           20      GB

# %%
df = pd.read_csv(r'riders-info.csv')

# %%
df.head()
# Out:
#   Riders All Time in All Classes  Victories  2nd places  3rd places  \
# 0               AGOSTINI Giacomo        122        35.0         2.0
# 1                ROSSI Valentino        115        67.0        53.0
# 2                    NIETO Angel         90        35.0        14.0
# 3                   MARQUEZ Marc         85        36.0        17.0
# 4                  HAILWOOD Mike         76        25.0        11.0
#
#    Pole positions from '74 to 2022  Race fastest lap to 2022  \
# 0                              9.0                     117.0
# 1                             65.0                      96.0
# 2                             34.0                      81.0
# 3                             90.0                      75.0
# 4                              NaN                      79.0
#
#    World Championships
# 0                 15.0
# 1                  9.0
# 2                 13.0
# 3                  8.0
# 4                  9.0
